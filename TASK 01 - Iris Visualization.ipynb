# %% [markdown]
# # Task 1: Exploring and Visualizing the Iris Dataset
# **Internship:** DevelopersHub Corporation – AI/ML Engineering
#
# **Objective:** Load, inspect, and visualize the Iris dataset to understand data trends and distributions.
#
# **Dataset:** Iris Dataset (loaded via seaborn – no download needed!)

# %% [markdown]
# ## Step 1: Import Libraries

# %%
# Importing all required libraries
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

print("Libraries imported successfully!")

# %% [markdown]
# ## Step 2: Load the Dataset

# %%
# Load the Iris dataset directly from seaborn (no file download needed)
df = sns.load_dataset('iris')

# Show the first 5 rows
print("First 5 rows of the dataset:")
df.head()

# %% [markdown]
# ## Step 3: Inspect the Dataset

# %%
# Check the shape (rows, columns)
print("Shape of dataset:", df.shape)

# Check column names
print("\nColumn Names:", df.columns.tolist())

# Check data types and missing values
print("\nDataset Info:")
df.info()

# %%
# Summary statistics for all numeric columns
print("Summary Statistics:")
df.describe()

# %%
# Check how many samples exist per flower species
print("Species count:")
print(df['species'].value_counts())

# %% [markdown]
# ## Step 4: Visualizations
#
# ### 4a. Scatter Plot – Relationships Between Features

# %%
# Scatter plot: Sepal Length vs Sepal Width, colored by species
plt.figure(figsize=(8, 5))
sns.scatterplot(data=df, x='sepal_length', y='sepal_width', hue='species', palette='Set1')
plt.title('Scatter Plot: Sepal Length vs Sepal Width')
plt.xlabel('Sepal Length (cm)')
plt.ylabel('Sepal Width (cm)')
plt.legend(title='Species')
plt.tight_layout()
plt.show()

# Scatter plot: Petal Length vs Petal Width
plt.figure(figsize=(8, 5))
sns.scatterplot(data=df, x='petal_length', y='petal_width', hue='species', palette='Set2')
plt.title('Scatter Plot: Petal Length vs Petal Width')
plt.xlabel('Petal Length (cm)')
plt.ylabel('Petal Width (cm)')
plt.legend(title='Species')
plt.tight_layout()
plt.show()

# %% [markdown]
# ### 4b. Histograms – Value Distributions

# %%
# Histogram for all 4 numeric features
fig, axes = plt.subplots(2, 2, figsize=(12, 8))
features = ['sepal_length', 'sepal_width', 'petal_length', 'petal_width']

for i, feature in enumerate(features):
    ax = axes[i // 2][i % 2]
    sns.histplot(data=df, x=feature, hue='species', kde=True, ax=ax, palette='Set1')
    ax.set_title(f'Distribution of {feature.replace("_", " ").title()}')
    ax.set_xlabel(feature.replace('_', ' ').title())

plt.suptitle('Histograms of Iris Features by Species', fontsize=14)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### 4c. Box Plots – Detecting Outliers

# %%
# Box plots for each feature grouped by species
fig, axes = plt.subplots(2, 2, figsize=(12, 8))

for i, feature in enumerate(features):
    ax = axes[i // 2][i % 2]
    sns.boxplot(data=df, x='species', y=feature, ax=ax, palette='pastel')
    ax.set_title(f'Box Plot: {feature.replace("_", " ").title()}')
    ax.set_xlabel('Species')
    ax.set_ylabel(feature.replace('_', ' ').title())

plt.suptitle('Box Plots of Iris Features by Species', fontsize=14)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### 4d. Bonus: Pair Plot – Full Overview

# %%
# Pair plot shows relationships between ALL feature pairs at once
sns.pairplot(df, hue='species', palette='Set1')
plt.suptitle('Pair Plot of Iris Dataset', y=1.02, fontsize=14)
plt.show()

# %% [markdown]
# ## Step 5: Key Insights and Conclusion

# %%
print("""
KEY INSIGHTS FROM THE IRIS DATASET:
=====================================
1. The dataset has 150 rows and 5 columns (4 features + 1 target).
2. There are 3 species: setosa, versicolor, and virginica — each with 50 samples.
3. There are NO missing values in this dataset.
4. PETAL features (length & width) are the best to distinguish species.
   - Setosa has clearly smaller petals than the other two species.
5. Sepal width has some outliers visible in the box plots.
6. Virginica tends to have the largest measurements overall.
""")
